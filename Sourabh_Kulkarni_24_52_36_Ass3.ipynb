# %% [markdown]
# <a href="https://colab.research.google.com/github/quicksourabh/sourabh_kulkarni_24_52_36/blob/main/Sourabh_Kulkarni_24_52_36_Ass3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Sourabh Kulkarni <br>
# Reg No : 24-52-36<br>
# DSTT- AM609

# %% [markdown]
# Q1.  Write a function that takes input (x,y) and returns MLE theta using Normal Equation.
# Use numpy in python to implement. Create a feature set x using linspace or np.random
# function and target values y. Call the function by passing these arguments and plot the
# precited values against input data.

# %% [markdown]
# The Normal Equation is a closed-form solution to find the parameters (theta) for linear regression.
#
# The formula is:
#
# 𝜃
# =
# (
# 𝑋
# 𝑇
# 𝑋
# )
# −
# 1
# 𝑋
# 𝑇
# 𝑦
# θ=(X
# T
#  X)
# −1
#  X
# T
#  y

# %%
import numpy as np
import matplotlib.pyplot as plt

# Linear regression using Normal Equation
def normal_equation(X, y):
    # Add a column of ones to X for the intercept term (bias)
    X_bias = np.c_[np.ones((X.shape[0], 1)), X]

    # Apply the normal equation: theta = (X^T * X)^(-1) * X^T * y
    theta = np.linalg.inv(X_bias.T @ X_bias) @ X_bias.T @ y
    return theta

# Generate input data (features) and target values
np.random.seed(42)  # For reproducibility
X = np.linspace(0, 10, 50).reshape(-1, 1)
y = 3 * X + np.random.randn(50, 1) * 2  # True slope = 3, noise added

# Get the MLE theta using the normal equation
theta = normal_equation(X, y)

# Predict the values using the learned parameters
X_bias = np.c_[np.ones((X.shape[0], 1)), X]
y_pred = X_bias @ theta

# Plot the original data and the predicted line
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Linear Regression Prediction')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression using Normal Equation')
plt.show()

# %% [markdown]
# Q2. Write a program to implement polynomial regression and compare it with the result
# obtained in the last question by plotting both the hypothesis.

# %% [markdown]
# Polynomial Regression allows fitting a curve to data instead of a straight line. We generate higher-degree features for input
# 𝑋
# X to fit a polynomial.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Polynomial regression function
def polynomial_regression(X, y, degree=2):
    poly_features = PolynomialFeatures(degree)
    X_poly = poly_features.fit_transform(X)
    model = LinearRegression().fit(X_poly, y)
    return model, X_poly

# Train polynomial regression and predict
poly_model, X_poly = polynomial_regression(X, y, degree=3)
y_poly_pred = poly_model.predict(X_poly)

# Plot both Linear and Polynomial Regression
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Linear Regression')
plt.plot(X, y_poly_pred, color='green', linestyle='--', label='Polynomial Regression (Degree=3)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Linear vs Polynomial Regression')
plt.show()

# %% [markdown]
# Q3 Access the effects of outliers while training a linear regression by introducing some out-
# liers in the data. Propose a solution how these outliers can be detected and removed
#
# before training the model. Implement the solution in python.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Polynomial regression function
def polynomial_regression(X, y, degree=2):
    poly_features = PolynomialFeatures(degree)
    X_poly = poly_features.fit_transform(X)
    model = LinearRegression().fit(X_poly, y)
    return model, X_poly

# Train polynomial regression and predict
poly_model, X_poly = polynomial_regression(X, y, degree=3)
y_poly_pred = poly_model.predict(X_poly)

# Plot both Linear and Polynomial Regression
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label='Linear Regression')
plt.plot(X, y_poly_pred, color='green', linestyle='--', label='Polynomial Regression (Degree=3)')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Linear vs Polynomial Regression')
plt.show()

# %% [markdown]
# Outliers significantly affect the performance of linear regression, as shown in the plot where the prediction line deviates due to a few outlier points. We used Z-score to detect and remove these outliers, leading to a more accurate fit.
